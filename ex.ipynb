# %%
from sklearn.cluster import KMeans
import pandas as pd 
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt 
# %matplotlib inline

# %%
df=pd.read_csv("Nutrition.csv")
df.head()
# Out:
#                      food_name  energy_kj  energy_kcal  carb_g  protein_g  \
# 0         Hot tea (Garam Chai)      68.16        16.14    2.58       0.39
# 1               Instant coffee      97.77        23.16    3.65       0.64
# 2               Espreso coffee     217.00        51.54    6.62       1.75
# 3                     Iced tea      44.09        10.34    2.70       0.03
# 4  Raw mango drink (Aam panna)     152.39        35.92    9.05       0.16
#
#    fat_g  freesugar_g  fibre_g cholesterol_mg  calcium_mg Meal Time Meal Type
# 0   0.53         2.58     0.00              0       14.20   Bevrage       veg
# 1   0.75         3.62     0.00              0       20.87   Bevrage       veg
# 2   2.14         6.53     0.00              0       58.10   Bevrage       veg
# 3   0.01         2.70     0.00              0        1.18   Bevrage       veg
# 4   0.03         7.49     0.61              0        7.08   Bevrage       veg

# %%
plt.scatter(df['food_name'],df['energy_kj'])

# %%
plt.scatter(df['food_name'],df['energy_kcal'])

# %%
plt.scatter(df['food_name'],df['carb_g'])

# %%
plt.scatter(df['food_name'],df['protein_g'])

# %%
plt.scatter(df['food_name'],df['fat_g'])

# %%
plt.scatter(df['food_name'],df['fibre_g'])

# %%
plt.scatter(df['food_name'],df['Meal Time'])

# %%
data = pd.read_csv('Nutrition.csv')
X = data.select_dtypes(include=['number']).dropna().values 
inertia = []
k_values = range(2, 11)  
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)  
   

plt.figure(figsize=(8, 5))
plt.plot(k_values, inertia, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia (WCSS)')
plt.show()

# %%
km=KMeans(n_clusters=4)
km
# Out:
# KMeans(n_clusters=4)
